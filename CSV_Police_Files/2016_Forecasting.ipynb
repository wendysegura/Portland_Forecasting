# %%
import pandas as pd
df = pd.read_csv('NIJ2016.csv')

# %%
df.head()
# Out:
#         CATEGORY CALL GROUPS final_case_type  \
# 0  STREET CRIMES    DISORDER          DISTP
# 1  STREET CRIMES    DISORDER          DISTP
# 2  STREET CRIMES    DISORDER          DISTP
# 3  STREET CRIMES    DISORDER          DISTP
# 4  STREET CRIMES    DISORDER          DISTP
#
#                                            CASE DESC occ_date  x_coordinate  \
# 0  DISTURBANCE - PRIORITY                        ...   8/1/16       7639201
# 1  DISTURBANCE - PRIORITY                        ...   8/1/16       7640405
# 2  DISTURBANCE - PRIORITY                        ...   8/1/16       7644614
# 3  DISTURBANCE - PRIORITY                        ...   8/1/16       7646589
# 4  DISTURBANCE - PRIORITY                        ...   8/1/16       7650579
#
#    y_coordinate  census_tract
# 0        683983        5200.0
# 1        684344        5200.0
# 2        686128        5100.0
# 3        686939        2303.0
# 4        687362        2402.0

# %%
import pandas as pd
df = pd.read_csv('NIJ2015.csv')

# %%
df
# Out:
#              CATEGORY     CALL GROUPS final_case_type  \
# 0       STREET CRIMES        DISORDER          DISTP
# 1       STREET CRIMES        DISORDER          DISTP
# 2       STREET CRIMES        DISORDER          DISTP
# 3       STREET CRIMES        DISORDER          DISTP
# 4       STREET CRIMES        DISORDER          DISTP
# 5       STREET CRIMES        DISORDER          DISTP
# 6       STREET CRIMES        DISORDER          DISTP
# 7       STREET CRIMES        DISORDER          DISTP
# 8       STREET CRIMES        DISORDER          DISTP
# 9       STREET CRIMES        DISORDER          DISTP
# 10      STREET CRIMES        DISORDER          DISTP
# 11      STREET CRIMES        DISORDER          DISTP
# 12      STREET CRIMES        DISORDER          DISTP
# 13      STREET CRIMES        DISORDER          DISTP
# 14      STREET CRIMES        DISORDER          DISTP
# 15      STREET CRIMES        DISORDER          DISTP
# 16      STREET CRIMES        DISORDER          DISTP
# ...

# %%
import pandas as pd
df = pd.read_csv('NIJ2015.csv')

# %%
df
# Out:
#              CATEGORY     CALL GROUPS final_case_type  \
# 0       STREET CRIMES        DISORDER          DISTP
# 1       STREET CRIMES        DISORDER          DISTP
# 2       STREET CRIMES        DISORDER          DISTP
# 3       STREET CRIMES        DISORDER          DISTP
# 4       STREET CRIMES        DISORDER          DISTP
# 5       STREET CRIMES        DISORDER          DISTP
# 6       STREET CRIMES        DISORDER          DISTP
# 7       STREET CRIMES        DISORDER          DISTP
# 8       STREET CRIMES        DISORDER          DISTP
# 9       STREET CRIMES        DISORDER          DISTP
# 10      STREET CRIMES        DISORDER          DISTP
# 11      STREET CRIMES        DISORDER          DISTP
# 12      STREET CRIMES        DISORDER          DISTP
# 13      STREET CRIMES        DISORDER          DISTP
# 14      STREET CRIMES        DISORDER          DISTP
# 15      STREET CRIMES        DISORDER          DISTP
# 16      STREET CRIMES        DISORDER          DISTP
# ...

# %%
import pandas as pd
df = pd.read_csv('NIJ2014.csv')

# %%
df
# Out:
#              CATEGORY     CALL GROUPS final_case_type  \
# 0       STREET CRIMES        DISORDER          DISTP
# 1       STREET CRIMES        DISORDER          DISTP
# 2       STREET CRIMES        DISORDER          DISTP
# 3       STREET CRIMES        DISORDER          DISTP
# 4       STREET CRIMES        DISORDER          DISTP
# 5       STREET CRIMES        DISORDER          DISTP
# 6       STREET CRIMES        DISORDER          DISTP
# 7       STREET CRIMES        DISORDER          DISTP
# 8       STREET CRIMES        DISORDER          DISTP
# 9       STREET CRIMES        DISORDER          DISTP
# 10      STREET CRIMES        DISORDER          DISTP
# 11      STREET CRIMES        DISORDER          DISTP
# 12      STREET CRIMES        DISORDER          DISTP
# 13      STREET CRIMES        DISORDER          DISTP
# 14      STREET CRIMES        DISORDER          DISTP
# 15      STREET CRIMES        DISORDER          DISTP
# 16      STREET CRIMES        DISORDER          DISTP
# ...

# %%
import pandas as pd
df = pd.read_csv('NIJ2013.csv')

# %%
df
# Out:
#              CATEGORY     CALL GROUPS final_case_type  \
# 0       STREET CRIMES        DISORDER          DISTP
# 1       STREET CRIMES        DISORDER          DISTP
# 2       STREET CRIMES        DISORDER          DISTP
# 3       STREET CRIMES        DISORDER          DISTP
# 4       STREET CRIMES        DISORDER          DISTP
# 5       STREET CRIMES        DISORDER          DISTP
# 6       STREET CRIMES        DISORDER          DISTP
# 7       STREET CRIMES        DISORDER          DISTP
# 8       STREET CRIMES        DISORDER          DISTP
# 9       STREET CRIMES        DISORDER          DISTP
# 10      STREET CRIMES        DISORDER          DISTP
# 11      STREET CRIMES        DISORDER          DISTP
# 12      STREET CRIMES        DISORDER          DISTP
# 13      STREET CRIMES        DISORDER          DISTP
# 14      STREET CRIMES        DISORDER          DISTP
# 15      STREET CRIMES        DISORDER          DISTP
# 16      STREET CRIMES        DISORDER          DISTP
# ...
